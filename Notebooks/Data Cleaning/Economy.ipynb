# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('acs_select_econ_08to12_ntas.xlsx - ACS_12_5YR_DP03.csv')
df.head()
# Out:
#                      Unnamed: 0 BK72 Williamsburg BK73 North Side-South Side  \
# 0             EMPLOYMENT STATUS               NaN                        NaN
# 1  Population 16 years and over            18,567                     37,813
# 2                In labor force             8,407                     27,062
# 3          Civilian labor force             8,407                     27,035
# 4                      Employed             7,970                     25,281
#
#   BK76 Greenpoint BK90 East Williamsburg BK09 Brooklyn Heights-Cobble Hill  \
# 0             NaN                    NaN                               NaN
# 1          28,667                 29,431                            20,750
# 2          21,148                 19,727                            14,848
# 3          21,138                 19,711                            14,848
# 4          19,849                 18,002                            14,060
#
# ...

# %%
df.set_index(keys = 'Unnamed: 0', inplace = True)
df.index.rename('Parameters', inplace = True)
df.head()
# Out:
#                              BK72 Williamsburg BK73 North Side-South Side  \
# Parameters
# EMPLOYMENT STATUS                          NaN                        NaN
# Population 16 years and over            18,567                     37,813
#    In labor force                        8,407                     27,062
#        Civilian labor force              8,407                     27,035
#           Employed                       7,970                     25,281
#
#                              BK76 Greenpoint BK90 East Williamsburg  \
# Parameters
# EMPLOYMENT STATUS                        NaN                    NaN
# Population 16 years and over          28,667                 29,431
#    In labor force                     21,148                 19,727
#        Civilian labor force           21,138                 19,711
#           Employed                    19,849                 18,002
#
#                              BK09 Brooklyn Heights-Cobble Hill  \
# Parameters
# ...

# %%
df.dropna(how = 'all', inplace = True)
df.head()
# Out:
#                              BK72 Williamsburg BK73 North Side-South Side  \
# Parameters
# Population 16 years and over            18,567                     37,813
#    In labor force                        8,407                     27,062
#        Civilian labor force              8,407                     27,035
#           Employed                       7,970                     25,281
#           Unemployed                       437                      1,754
#
#                              BK76 Greenpoint BK90 East Williamsburg  \
# Parameters
# Population 16 years and over          28,667                 29,431
#    In labor force                     21,148                 19,727
#        Civilian labor force           21,138                 19,711
#           Employed                    19,849                 18,002
#           Unemployed                   1,289                  1,709
#
#                              BK09 Brooklyn Heights-Cobble Hill  \
# Parameters
# ...

# %%
df = df.astype('str')

for col in df.columns[1:]:
    df[col] = df[col].str.replace(',','')
    df[col] = df[col].str.replace('nan','0')
    df[col] = df[col].str.replace('-','')

# %%
for column in df.columns[1:]:
    df[column] = pd.to_numeric(df[column])

# %%
df.columns = df.columns.str.replace(" ","_")

# %%
df.head()
# Out:
#                              BK72_Williamsburg  BK73_North_Side-South_Side  \
# Parameters
# Population 16 years and over            18,567                       37813
#    In labor force                        8,407                       27062
#        Civilian labor force              8,407                       27035
#           Employed                       7,970                       25281
#           Unemployed                       437                        1754
#
#                               BK76_Greenpoint  BK90_East_Williamsburg  \
# Parameters
# Population 16 years and over            28667                   29431
#    In labor force                       21148                   19727
#        Civilian labor force             21138                   19711
#           Employed                      19849                   18002
#           Unemployed                     1289                    1709
#
#                               BK09_Brooklyn_Heights-Cobble_Hill  \
# ...

# %%
df.to_csv('/wingrdp/homedirs/ppw220/economy.csv')
